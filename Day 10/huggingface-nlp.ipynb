# %%
from transformers import pipeline

sentiment_model = pipeline(
    "sentiment-analysis",
    model="distilbert/distilbert-base-uncased-finetuned-sst-2-english"
)

print(sentiment_model("Movie was amazing")) O one point twenty two grant code runs laptop monote to laptop charges for right O one point twenty two grant code runs laptop monote to laptop charges for rights O one point twenty two grant code runs laptop monote to laptop charges for rights transform O one point twenty two grant code runs laptop monote to laptop charges for rights transform and O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a pla O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predic O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for tran O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using this co O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using this code we O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using this code we perded O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using this code we perded the positive O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using this code we perded the positive inpu O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using this code we perded the positive input is O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using this code we perded the positive input is positive O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using this code we perded the positive input is positive or negative O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using this code we perded the positive input is positive or negative same O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using this code we perded the positive input is positive or negative same like this O one point twenty two grant code runs laptop monote to laptop charges for rights transform and phase is a platform there we brain model and give the input and predict here is a code for today. This code for transform using this code we perded the positive input is positive or negative same like this use
# Out:
# ...
# model.safetensors: reconstructing file:   0%|          |  0.00B /  268MB
# model.safetensors: downloading bytes:           |  0.00B
# c:\Users\Ankita\AppData\Local\Programs\Python\Python314\Lib\site-packages\huggingface_hub\file_download.py:141: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Ankita\.cache\huggingface\hub\models--distilbert--distilbert-base-uncased-finetuned-sst-2-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
result = sentiment_model("The movie was terrible")

print(result)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9997640252113342}]

# %%
import transformers
print(transformers.__version__)
# Out:
# 5.15.0

# %%
import transformers
import sys

print("Transformers:", transformers.__version__)
print("Python:", sys.executable)
# Out:
# Transformers: 4.57.1
# Python: c:\Users\Ankita\AppData\Local\Programs\Python\Python314\python.exe

# %%
from transformers import pipeline

qa_model = pipeline(
    "question-answering",
    model="deepset/roberta-base-squad2"
)
# Out:
# model.safetensors:   0%|          | 0.00/496M [00:00<?, ?B/s]
# c:\Users\Ankita\AppData\Local\Programs\Python\Python314\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Ankita\.cache\huggingface\hub\models--deepset--roberta-base-squad2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
context = """
Python is a programming language created by Guido van Rossum.
It is widely used in data science, machine learning and web development.
"""

question = "Who created Python?"

result = qa_model(
    question=question,
    context=context
)

print(result)
# Out:
# {'score': 0.9693575457204133, 'start': 45, 'end': 61, 'answer': 'Guido van Rossum'}

# %%
generator = pipeline("text-generation")

result = generator(
    "Artificial Intelligence is",
    max_new_tokens=30
)

print(result)
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# c:\Users\Ankita\AppData\Local\Programs\Python\Python314\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Ankita\.cache\huggingface\hub\models--openai-community--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
from transformers import pipeline

summarizer = pipeline("summarization")

text = """
Artificial intelligence is a field of computer science that focuses on
creating systems that can perform tasks that normally require human
intelligence. These tasks include learning, reasoning, understanding
language, recognizing images, and making decisions.
"""

result = summarizer(
    text,
    max_length=40,
    min_length=15,
    do_sample=False
)

print(result) O one point twenty two grant code runs
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# c:\Users\Ankita\AppData\Local\Programs\Python\Python314\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Ankita\.cache\huggingface\hub\models--sshleifer--distilbart-cnn-12-6. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...
